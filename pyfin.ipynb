# %% [markdown]
# ## Import
#
# Import the requirements

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 5.7 MB 1.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 43 kB 4.3 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 20.2 MB 35.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 10.0 MB 7.8 MB/s eta 0:00:01    |█████████████████████████████▌  | 9.3 MB 7.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 107 kB 30.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 83 kB 6.6 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 67 kB 12.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 246 kB 18.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 510 kB 5.3 MB/s eta 0:00:01
# ...
#   Created wheel for multitasking: filename=multitasking-0.0.9-py3-none-any.whl size=8366 sha256=7b04a170553ae48a76b18e7027e6cd2b5c1cf5ec239eb46683e4c5f682dc7d59
#   Stored in directory: /home/addlema/.cache/pip/wheels/ae/25/47/4d68431a7ec1b6c4b5233365934b74c1d4e665bf5f968d363a
# ...

# %%
from pyfin.pyfin import Stock
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
import datetime as dt
start = dt.datetime(2019,5,1)
end = dt.datetime.now()

# %%
apple = Stock("AAPL", start, end)

# %%
apple.getData()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
apple.stock_data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-05-01  209.880005  215.309998  209.229996  210.520004  207.800110
# 2019-05-02  209.839996  212.649994  208.130005  209.149994  206.447800
# 2019-05-03  210.889999  211.839996  210.229996  211.750000  209.014221
# 2019-05-06  204.289993  208.839996  203.500000  208.479996  205.786469
# 2019-05-07  205.880005  207.419998  200.830002  202.860001  200.239075
# ...                ...         ...         ...         ...         ...
# 2020-04-29  284.730011  289.670013  283.890015  287.730011  287.730011
# 2020-04-30  289.959991  294.529999  288.350006  293.799988  293.799988
# 2020-05-01  286.250000  299.000000  285.850006  289.070007  289.070007
# 2020-05-04  289.170013  293.690002  286.320007  293.160004  293.160004
# 2020-05-05  295.059998  301.000000  294.459991  297.559998  297.559998
#
#               Volume
# Date
# 2019-05-01  64827300
# 2019-05-02  31996300
# 2019-05-03  20892400
# ...

# %%
apple.addMovingAverage(50)

# %%
apple.stock_data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-05-01  209.880005  215.309998  209.229996  210.520004  207.800110
# 2019-05-02  209.839996  212.649994  208.130005  209.149994  206.447800
# 2019-05-03  210.889999  211.839996  210.229996  211.750000  209.014221
# 2019-05-06  204.289993  208.839996  203.500000  208.479996  205.786469
# 2019-05-07  205.880005  207.419998  200.830002  202.860001  200.239075
# ...                ...         ...         ...         ...         ...
# 2020-04-29  284.730011  289.670013  283.890015  287.730011  287.730011
# 2020-04-30  289.959991  294.529999  288.350006  293.799988  293.799988
# 2020-05-01  286.250000  299.000000  285.850006  289.070007  289.070007
# 2020-05-04  289.170013  293.690002  286.320007  293.160004  293.160004
# 2020-05-05  295.059998  301.000000  294.459991  297.559998  297.559998
#
#               Volume      Sma_50
# Date
# 2019-05-01  64827300         NaN
# 2019-05-02  31996300         NaN
# ...

# %%
#self.stock_data.iloc[:,4].ewm(span=moving_average, adjust=False).mean()

# %%
apple.stock_data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-05-01  209.880005  215.309998  209.229996  210.520004  207.800110
# 2019-05-02  209.839996  212.649994  208.130005  209.149994  206.447800
# 2019-05-03  210.889999  211.839996  210.229996  211.750000  209.014221
# 2019-05-06  204.289993  208.839996  203.500000  208.479996  205.786469
# 2019-05-07  205.880005  207.419998  200.830002  202.860001  200.239075
# ...                ...         ...         ...         ...         ...
# 2020-04-29  284.730011  289.670013  283.890015  287.730011  287.730011
# 2020-04-30  289.959991  294.529999  288.350006  293.799988  293.799988
# 2020-05-01  286.250000  299.000000  285.850006  289.070007  289.070007
# 2020-05-04  289.170013  293.690002  286.320007  293.160004  293.160004
# 2020-05-05  295.059998  301.000000  294.459991  297.559998  297.559998
#
#               Volume      Sma_50
# Date
# 2019-05-01  64827300         NaN
# 2019-05-02  31996300         NaN
# ...

# %% [markdown]
# ## Get the adj close
#
# two methods to getting the column..

# %%
# by numeric id
apple.stock_data.iloc[:,4]
# Out:
# Date
# 2019-05-01    207.800110
# 2019-05-02    206.447800
# 2019-05-03    209.014221
# 2019-05-06    205.786469
# 2019-05-07    200.239075
#                  ...
# 2020-04-29    287.730011
# 2020-04-30    293.799988
# 2020-05-01    289.070007
# 2020-05-04    293.160004
# 2020-05-05    297.559998
# Name: Adj Close, Length: 256, dtype: float64

# %%
# by name
apple.stock_data['Adj Close']
# Out:
# Date
# 2019-05-01    207.800110
# 2019-05-02    206.447800
# 2019-05-03    209.014221
# 2019-05-06    205.786469
# 2019-05-07    200.239075
#                  ...
# 2020-04-29    287.730011
# 2020-04-30    293.799988
# 2020-05-01    289.070007
# 2020-05-04    293.160004
# 2020-05-05    297.559998
# Name: Adj Close, Length: 256, dtype: float64

# %% [markdown]
# ## find moving average

# %%
round(apple.stock_data['Adj Close'].ewm(span=10,adjust=False).mean())
# Out:
# Date
# 2019-05-01    208.0
# 2019-05-02    208.0
# 2019-05-03    208.0
# 2019-05-06    207.0
# 2019-05-07    206.0
#               ...
# 2020-04-29    279.0
# 2020-04-30    282.0
# 2020-05-01    283.0
# 2020-05-04    285.0
# 2020-05-05    287.0
# Name: Adj Close, Length: 256, dtype: float64
